# %% [markdown]
# ### Importing necessary libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 8.5 MB/s  eta 0:00:01
# Collecting branca
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=739ed7e13ebd9bcbc806ea8600cd972b5ebe10ad8f6459deef2c37a215c8b45a
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.5.0
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials

# %%
CLIENT_ID = 'J0HTOYKRKKVY40ATW20U000SOEJT5P3YJUKLFCNU2G3T1GI0'
CLIENT_SECRET = 'IOZQVCMK2ROFCHL1SYCYKATKXQMOFS5RQMTHB2TJBZMXYGZB'
ACCESS_TOKEN = 'ORDGFCJHVFJK0DYVNMR0EP301YE4KAZH0FIYZ3D1FJOFYNHW'
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: J0HTOYKRKKVY40ATW20U000SOEJT5P3YJUKLFCNU2G3T1GI0
# CLIENT_SECRET:IOZQVCMK2ROFCHL1SYCYKATKXQMOFS5RQMTHB2TJBZMXYGZB

# %%
address = 'Konak, izmir, TR'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 38.4173469 27.1303546

# %%
search_query_p = 'pizza'
radius_p = 2000
print(search_query_p + ' .... OK!')

search_query_b = 'burger'
radius_b = 2000
print(search_query_b + ' .... OK!')
# Out:
# pizza .... OK!
# burger .... OK!

# %%
url_p = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query_p, radius_p, 100)
print(url_p)

url_b = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query_b, radius_b, 100)
print(url_b)
# Out:
# https://api.foursquare.com/v2/venues/search?client_id=J0HTOYKRKKVY40ATW20U000SOEJT5P3YJUKLFCNU2G3T1GI0&client_secret=IOZQVCMK2ROFCHL1SYCYKATKXQMOFS5RQMTHB2TJBZMXYGZB&ll=38.4173469,27.1303546&oauth_token=ORDGFCJHVFJK0DYVNMR0EP301YE4KAZH0FIYZ3D1FJOFYNHW&v=20180604&query=pizza&radius=2000&limit=100
# https://api.foursquare.com/v2/venues/search?client_id=J0HTOYKRKKVY40ATW20U000SOEJT5P3YJUKLFCNU2G3T1GI0&client_secret=IOZQVCMK2ROFCHL1SYCYKATKXQMOFS5RQMTHB2TJBZMXYGZB&ll=38.4173469,27.1303546&oauth_token=ORDGFCJHVFJK0DYVNMR0EP301YE4KAZH0FIYZ3D1FJOFYNHW&v=20180604&query=burger&radius=2000&limit=100

# %%
results_p = requests.get(url_p).json()
results_b = requests.get(url_b).json()

# %%
# assign relevant part of JSON to venues
venues_p = results_p['response']['venues']
venues_b = results_b['response']['venues']

# tranform venues into a dataframe
dataframe_p = json_normalize(venues_p)

dataframe_b = json_normalize(venues_b)
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %% [markdown]
# ### Cleaning Pizza Restaurant Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns_p = ['name', 'categories'] + [col for col in dataframe_p.columns if col.startswith('location.')] + ['id']
dataframe_filtered_p = dataframe_p.loc[:, filtered_columns_p]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered_p['categories'] = dataframe_filtered_p.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered_p.columns = [column.split('.')[-1] for column in dataframe_filtered_p.columns]

dataframe_filtered_p
# Out:
#                                  name            categories  \
# 0                         Pizza Villa           Pizza Place
# 1               Palmiye Döner & Pizza           Pizza Place
# 2                         Tadım Pizza           Pizza Place
# 3                           Piu Pizza           Pizza Place
# 4               Luciano Pizza & Döner                  Café
# 5                         Pizza Pizza           Pizza Place
# 6                      Domino's Pizza           Pizza Place
# 7                         Pizza Pizza           Pizza Place
# 8                      Domino's Pizza           Pizza Place
# 9               Pizza Venedik Express           Pizza Place
# 10                     Domino's Pizza           Pizza Place
# 11                     Pasaport Pizza           Pizza Place
# 12           Paprica Ristorante&Pizza    Italian Restaurant
# 13                        Pizza Pizza           Pizza Place
# 14                      Pizza Ravelle           Pizza Place
# 15                        Pizza Besst           Pizza Place
# 16                   Cafe Pizza Bella           Pizza Place
# 17                     La Pizza Sfida                  None
# 18                      Ege Fil Pizza           Pizza Place
# 19                Fil Pizza/Kemeraltı           Pizza Place
# 20                     Pasaport Pizza           Pizza Place
# 21                       Pizza Locale           Pizza Place
# 22                          Piu Pizza           Pizza Place
# 23  Karataş Pide-Pizza-Çorba ve Kebap            Pide Place
# 24     Tadım kahvaltı ve pizza salonu        Breakfast Spot
# 25                      Mabella Pizza           Pizza Place
# 26                        Pizza Villa           Pizza Place
# 27                     kopernik pizza           Pizza Place
# 28                 pizza pizza gümrük           Pizza Place
# 29                        Pizza Pizza           Pizza Place
# 30                            pızza x  Fast Food Restaurant
# 31                        Pizza Biziz           Pizza Place
# 32                        pizza pizza   Moroccan Restaurant
# 33       Besst Pizza Süleyman Dünyası           Pizza Place
# 34                    Tlg pizza pizza  Fast Food Restaurant
# 35                      Vitamin Pizza  Fast Food Restaurant
# 36                        Pizza Pizza  Fast Food Restaurant
# 37                         pizza mina           Pizza Place
# 38                      vitamin pizza           Pizza Place
# 39                        Pizza Pizza           Pizza Place
# 40          TLG Chicken / Pizza Pizza           Pizza Place
# 41                       Panino Pizza           Pizza Place
# 42                    Pizzaport Pizza           Pizza Place
# 43    İzmir Karabağlar Domino's Pizza                 Hotel
# 44                         Luwi Pizza           Pizza Place
# 45                       panino pizza           Pizza Place
# 46                         Pizza Piza           Pizza Place
# 47             Pizza Venedik Expresss           Pizza Place
# 48                         pizza cafe                  Café
# 49                       Mangal Pizza  Fast Food Restaurant
#
#                                            address  \
# 0                      Konak Mah. 846. Sok. No:5/A
# 1                            Fevzipaşa Blv. No:12B
# 2                                   859 sokak No:4
# 3                             857 Sokak No:2 Konak
# 4                                              NaN
# 5                                         Pasaport
# 6                  Hasan Tahsin Cad. No:16/A Hatay
# 7                                  İnönü Cd. Üçyol
# 8                                         Pasaport
# 9                       1379 Sok. No:53/B Alsancak
# 10                     Sevgiyolu 1379 Sokak No 57b
# 11                         Cumhuriyet Blv. No:77/A
# 12  Kültür Mah. Dr. Mustafa Enver Bey Cad. No:30/A
# 13                                      İzmir Park
# 14                                             NaN
# 15                                     853 S  N 32
# 16                                       Konak Mh.
# 17                                             NaN
# 18                       Salepçioğlu Vakıf Çarşısı
# 19                                           Vakıf
# 20                                Hasan Tahsin Cd.
# 21            Kültür Mah. 1390 Sk. No:5/B Alsancak
# 22                 Cumhuriyet Blv. 859. Sk. No:5/E
# 23                 Mithatpaşa Cad. No:81/A Karataş
# 24                                             NaN
# 25                                             NaN
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                Hasan Tahsin Cd.
# 30                                             NaN
# 31                                             NaN
# 32                                             NaN
# 33                                             NaN
# 34                                             NaN
# 35                                             NaN
# 36                                       Eşrefpaşa
# 37                                             NaN
# 38                                             NaN
# 39                                             NaN
# 40                                             NaN
# 41                                             NaN
# 42                        Hasan Tahsin Cd. No:39/B
# 43                                             NaN
# 44                                 Mimar Sinan Mh.
# 45                                             NaN
# 46                                     Pizza Pizza
# 47                                             NaN
# 48                                             NaN
# 49                                             NaN
#
#                    crossStreet        lat        lng  \
# 0             Kemeraltı Şubesi  38.418143  27.130593
# 1                          NaN  38.422516  27.132295
# 2                          NaN  38.420868  27.130735
# 3                          NaN  38.420827  27.130185
# 4                          NaN  38.420832  27.130486
# 5              Ataturk Caddesi  38.425643  27.134859
# 6                          NaN  38.401847  27.115513
# 7                          NaN  38.406203  27.121288
# 8                          NaN  38.426528  27.132965
# 9                          NaN  38.426880  27.137144
# 10                         NaN  38.426681  27.136868
# 11                     NO:77/A  38.426219  27.132734
# 12                         NaN  38.432021  27.142186
# 13                         NaN  38.403386  27.128744
# 14                         NaN  38.418237  27.130861
# 15                 İzsu Sokağı  38.420032  27.130934
# 16                         NaN  38.417916  27.129172
# 17                         NaN  38.418086  27.129339
# 18         Anafartalar Caddesi  38.417798  27.132187
# 19  Kemeraltı Vakıflar Çarşısı  38.417767  27.132216
# 20                         NaN  38.401731  27.115379
# 21                         NaN  38.432516  27.142775
# 22                         NaN  38.420762  27.130170
# 23                         NaN  38.411339  27.121656
# 24                         NaN  38.420834  27.130948
# 25                         NaN  38.416733  27.136233
# 26                         NaN  38.423466  27.142128
# 27                         NaN  38.419632  27.136827
# 28                         NaN  38.425511  27.134682
# 29                         NaN  38.401926  27.115687
# 30                         NaN  38.424450  27.135902
# 31                         NaN  38.426821  27.138640
# 32                         NaN  38.405749  27.128439
# 33                         NaN  38.421715  27.139717
# 34                         NaN  38.425547  27.134549
# 35                         NaN  38.422780  27.140237
# 36           Eşrefpaşa Caddesi  38.403287  27.128793
# 37                         NaN  38.398567  27.122072
# 38                         NaN  38.422580  27.140200
# 39                         NaN  38.403386  27.128759
# 40                         NaN  38.426067  27.135414
# 41                         NaN  38.424463  27.148336
# 42                         NaN  38.401341  27.114876
# 43                         NaN  38.423733  27.142826
# 44              Hürriyet Bulv.  38.424357  27.141826
# 45                         NaN  38.417944  27.146354
# 46            Kıbrıs Şehitleri  38.435876  27.130557
# 47                         NaN  38.406197  27.110400
# 48                         NaN  38.430679  27.149141
# 49                         NaN  38.424595  27.144835
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 38.41814340648098...        91      35250
# 1   [{'label': 'display', 'lat': 38.42251572886116...       599      35250
# 2   [{'label': 'display', 'lat': 38.4208681032727,...       393        NaN
# 3   [{'label': 'display', 'lat': 38.4208267644605,...       387        NaN
# 4   [{'label': 'display', 'lat': 38.420832, 'lng':...       388        NaN
# 5   [{'label': 'display', 'lat': 38.42564284452234...      1003        NaN
# 6   [{'label': 'display', 'lat': 38.40184729867597...      2157      35150
# 7   [{'label': 'display', 'lat': 38.40620290923130...      1471        NaN
# 8   [{'label': 'display', 'lat': 38.42652828963122...      1047      35220
# 9   [{'label': 'display', 'lat': 38.42687962570959...      1215      35615
# 10  [{'label': 'display', 'lat': 38.42668144010907...      1184        NaN
# 11  [{'label': 'display', 'lat': 38.42621943498236...      1009      35350
# 12  [{'label': 'display', 'lat': 38.43202149300532...      1932      35220
# 13  [{'label': 'display', 'lat': 38.40338584799239...      1560        NaN
# 14  [{'label': 'display', 'lat': 38.418237, 'lng':...       108        NaN
# 15  [{'label': 'display', 'lat': 38.42003224020143...       303        NaN
# 16  [{'label': 'display', 'lat': 38.41791589540613...       121        NaN
# 17  [{'label': 'display', 'lat': 38.41808568650375...       120        NaN
# 18  [{'label': 'display', 'lat': 38.4177979083248,...       167        NaN
# 19  [{'label': 'display', 'lat': 38.41776650101774...       168        NaN
# 20  [{'label': 'display', 'lat': 38.40173149182274...      2174        NaN
# 21  [{'label': 'display', 'lat': 38.43251588081878...      2006      35220
# 22  [{'label': 'display', 'lat': 38.42076220730614...       380        NaN
# 23  [{'label': 'display', 'lat': 38.41133896495129...      1011        NaN
# 24  [{'label': 'display', 'lat': 38.42083414810933...       391        NaN
# 25  [{'label': 'display', 'lat': 38.41673326879405...       517        NaN
# 26  [{'label': 'display', 'lat': 38.423466, 'lng':...      1232        NaN
# 27  [{'label': 'display', 'lat': 38.41963195800781...       619        NaN
# 28  [{'label': 'display', 'lat': 38.42551091952320...       984        NaN
# 29  [{'label': 'display', 'lat': 38.40192617490304...      2140        NaN
# 30  [{'label': 'display', 'lat': 38.42445, 'lng': ...       926        NaN
# 31  [{'label': 'display', 'lat': 38.42682125126011...      1278        NaN
# 32  [{'label': 'display', 'lat': 38.405749, 'lng':...      1301        NaN
# 33  [{'label': 'display', 'lat': 38.421715, 'lng':...       950        NaN
# 34  [{'label': 'display', 'lat': 38.4255466580885,...       983        NaN
# 35  [{'label': 'display', 'lat': 38.42278027285251...      1052        NaN
# 36  [{'label': 'display', 'lat': 38.40328689856378...      1571        NaN
# 37  [{'label': 'display', 'lat': 38.39856735030256...      2211        NaN
# 38  [{'label': 'display', 'lat': 38.42258045044902...      1037        NaN
# 39  [{'label': 'display', 'lat': 38.40338610691535...      1560        NaN
# 40  [{'label': 'display', 'lat': 38.42606735229492...      1066        NaN
# 41  [{'label': 'display', 'lat': 38.4244631928312,...      1756        NaN
# 42  [{'label': 'display', 'lat': 38.40134127556511...      2235      35150
# 43  [{'label': 'display', 'lat': 38.423733, 'lng':...      1299      35210
# 44  [{'label': 'display', 'lat': 38.42435684384718...      1268        NaN
# 45  [{'label': 'display', 'lat': 38.41794356931566...      1397        NaN
# 46  [{'label': 'display', 'lat': 38.43587551412597...      2062      35220
# 47  [{'label': 'display', 'lat': 38.406197, 'lng':...      2137      35280
# 48  [{'label': 'display', 'lat': 38.43067932128906...      2210        NaN
# 49  [{'label': 'display', 'lat': 38.424595, 'lng':...      1498        NaN
#
#     cc neighborhood            city  state  country  \
# 0   TR        Konak           Konak  İzmir  Türkiye
# 1   TR          NaN           Konak  İzmir  Türkiye
# 2   TR          NaN           İzmir  İzmir  Türkiye
# 3   TR          NaN           İzmir  İzmir  Türkiye
# 4   TR          NaN           Konak  İzmir  Türkiye
# 5   TR          NaN           Konak  İzmir  Türkiye
# 6   TR          NaN           İzmir  İzmir  Türkiye
# 7   TR          NaN           İzmir  İzmir  Türkiye
# 8   TR          NaN           Konak  İzmir  Türkiye
# 9   TR          NaN           İzmir  İzmir  Türkiye
# 10  TR          NaN           İzmir  İzmir  Türkiye
# 11  TR          NaN           İzmir  İzmir  Türkiye
# 12  TR          NaN           İzmir  İzmir  Türkiye
# 13  TR          NaN           İzmir  İzmir  Türkiye
# 14  TR          NaN             NaN    NaN  Türkiye
# 15  TR          NaN           İzmir  35400  Türkiye
# 16  TR          NaN  İzmir Province    NaN  Türkiye
# 17  TR          NaN             NaN    NaN  Türkiye
# 18  TR          NaN           İzmir  İzmir  Türkiye
# 19  TR          NaN           Konak  İzmir  Türkiye
# 20  TR          NaN           İzmir  İzmir  Türkiye
# 21  TR          NaN           Konak  İzmir  Türkiye
# 22  TR          NaN           Konak  İzmir  Türkiye
# 23  TR          NaN           İzmir  İzmir  Türkiye
# 24  TR          NaN             NaN    NaN  Türkiye
# 25  TR          NaN           Konak  İzmir  Türkiye
# 26  TR          NaN             NaN    NaN  Türkiye
# 27  TR          NaN             NaN    NaN  Türkiye
# 28  TR          NaN             NaN    NaN  Türkiye
# 29  TR          NaN           İzmir  İzmir  Türkiye
# 30  TR          NaN             NaN    NaN  Türkiye
# 31  TR          NaN             NaN    NaN  Türkiye
# 32  TR          NaN             NaN    NaN  Türkiye
# 33  TR          NaN             NaN    NaN  Türkiye
# 34  TR          NaN             NaN    NaN  Türkiye
# 35  TR          NaN             NaN    NaN  Türkiye
# 36  TR          NaN           İzmir  İzmir  Türkiye
# 37  TR          NaN             NaN    NaN  Türkiye
# 38  TR          NaN             NaN    NaN  Türkiye
# 39  TR          NaN             NaN    NaN  Türkiye
# 40  TR          NaN             NaN    NaN  Türkiye
# 41  TR          NaN             NaN    NaN  Türkiye
# 42  TR          NaN           İzmir  İzmir  Türkiye
# 43  TR          NaN             NaN  İzmir  Türkiye
# 44  TR          NaN           İzmir  İzmir  Türkiye
# 45  TR          NaN             NaN    NaN  Türkiye
# 46  TR          NaN           İzmir  İzmir  Türkiye
# 47  TR          NaN             NaN  İzmir  Türkiye
# 48  TR          NaN             NaN    NaN  Türkiye
# 49  TR          NaN             NaN    NaN  Türkiye
#
#                                      formattedAddress  \
# 0   [Konak Mah. 846. Sok. No:5/A (Kemeraltı Şubesi...
# 1                [Fevzipaşa Blv. No:12B, 35250 izmir]
# 2                             [859 sokak No:4, İzmir]
# 3                       [857 Sokak No:2 Konak, İzmir]
# 4                                             [Konak]
# 5                 [Pasaport (Ataturk Caddesi), Konak]
# 6      [Hasan Tahsin Cad. No:16/A Hatay, 35150 İzmir]
# 7                            [İnönü Cd. Üçyol, İzmir]
# 8                             [Pasaport, 35220 İzmir]
# 9           [1379 Sok. No:53/B Alsancak, 35615 İzmir]
# 10               [Sevgiyolu 1379 Sokak No 57b, İzmir]
# 11   [Cumhuriyet Blv. No:77/A (NO:77/A), 35350 İzmir]
# 12  [Kültür Mah. Dr. Mustafa Enver Bey Cad. No:30/...
# 13                                [İzmir Park, İzmir]
# 14                                                NaN
# 15                 [853 S  N 32 (İzsu Sokağı), İzmir]
# 16                        [Konak Mh., İzmir Province]
# 17                                                NaN
# 18  [Salepçioğlu Vakıf Çarşısı (Anafartalar Caddes...
# 19        [Vakıf (Kemeraltı Vakıflar Çarşısı), İzmir]
# 20                          [Hasan Tahsin Cd., İzmir]
# 21  [Kültür Mah. 1390 Sk. No:5/B Alsancak, 35220 K...
# 22           [Cumhuriyet Blv. 859. Sk. No:5/E, Konak]
# 23           [Mithatpaşa Cad. No:81/A Karataş, İzmir]
# 24                                                NaN
# 25                                            [Konak]
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                          [Hasan Tahsin Cd., İzmir]
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36             [Eşrefpaşa (Eşrefpaşa Caddesi), İzmir]
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42            [Hasan Tahsin Cd. No:39/B, 35150 İzmir]
# 43                                            [35210]
# 44          [Mimar Sinan Mh. (Hürriyet Bulv.), İzmir]
# 45                                                NaN
# 46      [Pizza Pizza (Kıbrıs Şehitleri), 35220 İzmir]
# 47                                            [35280]
# 48                                                NaN
# 49                                                NaN
#
#                           id
# 0   50ddad48f2e77b34594b4bcf
# 1   52c5a1f2498e1db1d503ad49
# 2   4ef72df69a52c90840ef2fec
# 3   562e005a498e522c2da4cdba
# 4   5abbaf1cdd8442152333e576
# 5   4e673866aeb7e985aaa20240
# 6   4d0e1dc13905b1f7a60c9e4b
# 7   4d1355070e9e8eec12a3491c
# 8   4f097346e4b08f5249c71352
# 9   4c8f520ba8de224be6532e01
# 10  548ac45d498ecb54daa0e209
# 11  52d906ff498e30bf8ead9837
# 12  599c8d4c178a2a1608cf0342
# 13  54d72e7f498ea8e4d5de3ab8
# 14  4f5355e5e4b02d0eb45fcbf8
# 15  5ba10b748ad62e002c0f4c7d
# 16  4f146792e4b0aabf1ab17087
# 17  4fc77d95e4b0466555999862
# 18  56dad7dfcd105a91d9624cd4
# 19  56dd4f79498e8755e3f2f4fb
# 20  4fe442b0e4b0e27bc5cbb77e
# 21  55ffdde3498e58dc2381a311
# 22  4d9df20da1ec8cfaa325104a
# 23  53c82664498ec7a7ec93ea71
# 24  568f770c498e69eeb19f05c9
# 25  4e9478ad8b81ef41a9506edf
# 26  5b9d16a7c9a517002c359ca5
# 27  54b650ed498ef6705f07c9ba
# 28  50d35088e4b0602c95f917a1
# 29  4fbe3356e4b0a3912dca3ace
# 30  4e1eb78b2271ad66e4a1d721
# 31  51f75957498e2880611dfffc
# 32  56b11c19498e2610f9977c17
# 33  5ba64acb178a2a002cbf35f2
# 34  4f366091e4b0d9574bd16181
# 35  53aaa720498ea6ed88b15ddf
# 36  55266d6a498e3c99119d2487
# 37  52b5deca498eaa58960c870a
# 38  511cb862e4b07dfbcd64f384
# 39  54d8c455498ee1bc7e745771
# 40  52daa93c498eef3e2537e8d7
# 41  531c911c498e92595fcd817f
# 42  4f9e7de1e4b020e6112fe1f5
# 43  5d6134c00ad73a00085062f0
# 44  4d41453f7a516ea8b843c282
# 45  52481c4311d2be171103dd12
# 46  55698929498e95928da0595f
# 47  583ff3ea6f20d11b221e1bac
# 48  53cad182498e889ccf2f03f5
# 49  505ee449e4b011bf1f514d9e

# %% [markdown]
# ### Cleaning Burger Restaurant Dataframe

# %%
filtered_columns_b = ['name', 'categories'] + [col for col in dataframe_b.columns if col.startswith('location.')] + ['id']
dataframe_filtered_b = dataframe_b.loc[:, filtered_columns_b]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered_b['categories'] = dataframe_filtered_b.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered_b.columns = [column.split('.')[-1] for column in dataframe_filtered_b.columns]

dataframe_filtered_b
# Out:
#                            name            categories        lat        lng  \
# 0                   Burger King  Fast Food Restaurant  38.416406  27.128369
# 1                   Burger King  Fast Food Restaurant  38.422126  27.129206
# 2                   Burger No 7          Burger Joint  38.432755  27.142415
# 3                   Burger King  Fast Food Restaurant  38.428603  27.136513
# 4                   Burger King  Fast Food Restaurant  38.403354  27.128846
# 5           Piri Köfte & Burger          Burger Joint  38.433540  27.142247
# 6        Burger King Külah Büfe        Ice Cream Shop  38.418335  27.130104
# 7   Mengoli Burgers Steak Fries          Burger Joint  38.425583  27.134979
# 8          Burger King Dondurma        Ice Cream Shop  38.418466  27.125840
# 9      Beeves Burger&Steakhouse            Steakhouse  38.432641  27.140253
# 10                 Burger Rules          Burger Joint  38.422139  27.133271
# 11                 Onder Burger  Fast Food Restaurant  38.422340  27.131190
# 12             Burger King Café           Coffee Shop  38.427759  27.140809
# 13         Burger&Fried Chicken  Fast Food Restaurant  38.410956  27.121475
# 14           Rio Burger Kokoreç          Burger Joint  38.407135  27.123798
# 15     Burger RePUBlic Alsancak          Burger Joint  38.431198  27.139599
# 16             Burger King CAFE                  Café  38.427524  27.141058
# 17                    By Burger          Burger Joint  38.411046  27.121617
# 18       %100 Steakhouse&burger          Burger Joint  38.432503  27.140217
# 19              Burger Republic          Burger Joint  38.433096  27.140606
# 20             Mr. Asado Burger          Burger Joint  38.432054  27.141907
# 21               Tallguy Burger          Burger Joint  38.409579  27.118301
# 22          Fezz Burger & Köfte          Burger Joint  38.430470  27.135820
# 23     Bagel Burger Bar & Sushi    Chinese Restaurant  38.431387  27.140282
# 24                Modern Burger          Burger Joint  38.431623  27.140286
# 25    Popeyes Louisiana Kitchen   Fried Chicken Joint  38.427853  27.140855
# 26                  Burgerillas          Burger Joint  38.433815  27.142044
# 27     5th St. New York Burgers          Burger Joint  38.426224  27.136509
# 28            Friends & Burgers          Burger Joint  38.430491  27.135743
# 29               Sancak burgers          Burger Joint  38.409607  27.152271
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 38.41640638763128...       202      35170
# 1   [{'label': 'display', 'lat': 38.42212638141188...       541      35250
# 2   [{'label': 'display', 'lat': 38.43275505570964...      2012        NaN
# 3   [{'label': 'display', 'lat': 38.42860259660131...      1363        NaN
# 4   [{'label': 'display', 'lat': 38.40335362504463...      1563        NaN
# 5   [{'label': 'display', 'lat': 38.43353988733736...      2079        NaN
# 6   [{'label': 'display', 'lat': 38.418335, 'lng':...       112        NaN
# 7   [{'label': 'display', 'lat': 38.42558252480487...      1001        NaN
# 8   [{'label': 'display', 'lat': 38.41846597139359...       412        NaN
# 9   [{'label': 'display', 'lat': 38.432641, 'lng':...      1908        NaN
# 10  [{'label': 'display', 'lat': 38.422139, 'lng':...       590      35250
# 11  [{'label': 'display', 'lat': 38.42234, 'lng': ...       560        NaN
# 12  [{'label': 'display', 'lat': 38.427759, 'lng':...      1474        NaN
# 13  [{'label': 'display', 'lat': 38.410956, 'lng':...      1051        NaN
# 14  [{'label': 'display', 'lat': 38.407135, 'lng':...      1272        NaN
# 15  [{'label': 'display', 'lat': 38.431198, 'lng':...      1739      35220
# 16  [{'label': 'display', 'lat': 38.42752449815678...      1467        NaN
# 17  [{'label': 'display', 'lat': 38.41104608503168...      1035      35260
# 18  [{'label': 'display', 'lat': 38.432503, 'lng':...      1893      35220
# 19  [{'label': 'display', 'lat': 38.433096, 'lng':...      1967        NaN
# 20  [{'label': 'display', 'lat': 38.432054, 'lng':...      1922        NaN
# 21  [{'label': 'display', 'lat': 38.40957866293638...      1361        NaN
# 22  [{'label': 'display', 'lat': 38.43047, 'lng': ...      1536        NaN
# 23  [{'label': 'display', 'lat': 38.43138670766422...      1786        NaN
# 24  [{'label': 'display', 'lat': 38.43162284709018...      1809      35220
# 25  [{'label': 'display', 'lat': 38.42785335771369...      1485        NaN
# 26  [{'label': 'display', 'lat': 38.433815, 'lng':...      2097        NaN
# 27  [{'label': 'display', 'lat': 38.426224, 'lng':...      1124        NaN
# 28  [{'label': 'display', 'lat': 38.430491, 'lng':...      1536        NaN
# 29  [{'label': 'display', 'lat': 38.40960675435163...      2096        NaN
#
#     cc   city  state  country  \
# 0   TR  İzmir  İzmir  Türkiye
# 1   TR  Konak  İzmir  Türkiye
# 2   TR  İzmir  İzmir  Türkiye
# 3   TR  Konak  İzmir  Türkiye
# 4   TR  İzmir  İzmir  Türkiye
# 5   TR  İzmir  İzmir  Türkiye
# 6   TR    NaN    NaN  Türkiye
# 7   TR  İzmir  İzmir  Türkiye
# 8   TR    NaN    NaN  Türkiye
# 9   TR  İzmir  İzmir  Türkiye
# 10  TR  İzmir  İzmir  Türkiye
# 11  TR  Konak  İzmir  Türkiye
# 12  TR  İzmir  İzmir  Türkiye
# 13  TR    NaN    NaN  Türkiye
# 14  TR    NaN    NaN  Türkiye
# 15  TR  İzmir  İzmir  Türkiye
# 16  TR    NaN    NaN  Türkiye
# 17  TR  İzmir  İzmir  Türkiye
# 18  TR    NaN  İzmir  Türkiye
# 19  TR    NaN    NaN  Türkiye
# 20  TR  İzmir  İzmir  Türkiye
# 21  TR  İzmir  İzmir  Türkiye
# 22  TR  İzmir  İzmir  Türkiye
# 23  TR    NaN    NaN  Türkiye
# 24  TR  İzmir  İzmir  Türkiye
# 25  TR  Konak  İzmir  Türkiye
# 26  TR  İzmir  İzmir  Türkiye
# 27  TR  İzmir  İzmir  Türkiye
# 28  TR    NaN    NaN  Türkiye
# 29  TR    NaN    NaN  Türkiye
#
#                                      formattedAddress  \
# 0                                       [35170 İzmir]
# 1                       [Konak Pier AVM, 35250 Konak]
# 2                   [1389 Sokak No:7 Alsancak, İzmir]
# 3   [Şehit Nevres Blv. Alsancak (Swissotel Karşısı...
# 4                                 [İzmir Park, İzmir]
# 5      [Kültür Mahallesi 1388. Sokak No: 14/A, İzmir]
# 6                                                 NaN
# 7            [Vali Kazım Dirik Cad. No:34-44A, İzmir]
# 8                                                 NaN
# 9   [Dr. Mustafa Enver Bey Caddesi NO:9/B Alsancak...
# 10             [900 Sokak No:3 Hisarönü, 35250 İzmir]
# 11                                            [Konak]
# 12                            [Montrö Meydanı, İzmir]
# 13                                                NaN
# 14                                                NaN
# 15        [İtalya Sok. No:11/A Alsancak, 35220 İzmir]
# 16                                                NaN
# 17     [Mithatpaşa cad 91C (Mithatpaşa), 35260 İzmir]
# 18                                            [35220]
# 19                                                NaN
# 20        [Dr. Mustafa Enver Bey Cad. No:30/B, İzmir]
# 21  [Turgutreis Mahallesi (Mithat Pasa Caddesi 205...
# 22  [Cumhuriyet Bulvarı  no 135/A Alsancak İzmir (...
# 23                                                NaN
# 24                           [1379 sok., 35220 İzmir]
# 25                  [Şair Eşref Blv. No:35/1A, Konak]
# 26                                            [İzmir]
# 27  [Şevket Özçelik Sokak (Gazi Osman Paşa Bulvarı...
# 28                [Cumhuriyet Bul. No:135/A Alsancak]
# 29                                            [İzmir]
#
#                                           address            neighborhood  \
# 0                                             NaN                     NaN
# 1                                  Konak Pier AVM                     NaN
# 2                        1389 Sokak No:7 Alsancak                Alsancak
# 3                      Şehit Nevres Blv. Alsancak                     NaN
# 4                                      İzmir Park                     NaN
# 5           Kültür Mahallesi 1388. Sokak No: 14/A                     NaN
# 6                                             NaN                     NaN
# 7                 Vali Kazım Dirik Cad. No:34-44A                     NaN
# 8                                             NaN                     NaN
# 9   Dr. Mustafa Enver Bey Caddesi NO:9/B Alsancak        Kültür Mahallesi
# 10                        900 Sokak No:3 Hisarönü                     NaN
# 11                                            NaN                     NaN
# 12                                 Montrö Meydanı                     NaN
# 13                                            NaN                     NaN
# 14                                            NaN                     NaN
# 15                   İtalya Sok. No:11/A Alsancak                     NaN
# 16                                            NaN                     NaN
# 17                             Mithatpaşa cad 91C                     NaN
# 18                                            NaN                     NaN
# 19                                            NaN                     NaN
# 20             Dr. Mustafa Enver Bey Cad. No:30/B                     NaN
# 21                           Turgutreis Mahallesi                     NaN
# 22    Cumhuriyet Bulvarı  no 135/A Alsancak İzmir                     NaN
# 23                                            NaN                     NaN
# 24                                      1379 sok.                     NaN
# 25                       Şair Eşref Blv. No:35/1A  İsmet Kaptan Mahallesi
# 26                                            NaN                     NaN
# 27                           Şevket Özçelik Sokak                     NaN
# 28              Cumhuriyet Bul. No:135/A Alsancak                     NaN
# 29                                          İzmir                     NaN
#
#                  crossStreet                        id
# 0                        NaN  4d08aa4905216dcb0b291cb6
# 1                        NaN  4d31ba8d5c2db60c58e2ba6c
# 2                        NaN  5a998b1695a7222a9dee972a
# 3          Swissotel Karşısı  4c1b4c9db4e62d7fbd1cd993
# 4                        NaN  54ca7fb6498e95364d71dce2
# 5                        NaN  59c0f6366fd6261e3bd2ee09
# 6                        NaN  56966454498e67d80fc3cf9f
# 7                        NaN  5a13f65f16fa042ec85a2b2f
# 8                        NaN  53af0cbf498ec433ee90f38a
# 9                        NaN  56aa11ad498e7e4fd9e27295
# 10                       NaN  5c24dd318194fc002cc38c13
# 11                       NaN  50e43f0ae4b0a78b15cf43ab
# 12                       NaN  571362f3498e1084040842b4
# 13                       NaN  5c810051da2e00002c5679a6
# 14                       NaN  5f949820505d62684442107a
# 15                       NaN  5f7f283f13aafe7a59d3ef33
# 16                       NaN  56ea933c498e3d88681ae478
# 17                Mithatpaşa  58b4330458c4d129f8890975
# 18                       NaN  58b84d01ac3291404927788f
# 19                       NaN  5f1c4e4b68935a58c3334dae
# 20                       NaN  5db3005085b2a5000764a797
# 21  Mithat Pasa Caddesi 205A  593c61577269fe615656636e
# 22        Cumhuriyet Bulvarı  5c15123be55d8b002cdc0672
# 23                       NaN  514b2cb9e4b007e190b9cc59
# 24                       NaN  4e12cd5e1fc73bbd6229c6e2
# 25                       NaN  55b8ea7e498e9beac18b3e6c
# 26                       NaN  5de27febfea4da0008341f51
# 27   Gazi Osman Paşa Bulvarı  5c82a477f05ca8002d8ab2b9
# 28                       NaN  5d729e294c6f7c00082db6df
# 29                       NaN  51ed1514498e38690ddc4769

# %% [markdown]
# ### Visualization of Burger Restaurant in "red" and Pizza Restaurant in "blue"

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add the Pizza Restaurent as blue circle markers
for lat, lng, label in zip(dataframe_filtered_p.lat, dataframe_filtered_p.lng, dataframe_filtered_p.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

    # add the Burger Restaurent as red circle markers
for lat, lng, label in zip(dataframe_filtered_b.lat, dataframe_filtered_b.lng, dataframe_filtered_b.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)
    
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_c78e30982803454bba0ebccea3d335d0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c78e30982803454bba0ebccea3d335d0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c78e30982803454bba0ebccea3d335d0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_c78e30982803454bba0ebccea3d335d0%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B38.4173469%2C27.1303546%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %%
#Import required libraries
from tkinter import *
from PIL import ImageTk, Image

#Create an instance of tkinter window
win =Tk()

#Define the geometry of the window
win.geometry("650x400")

#Initialize the file name in a variable
path = "\Users\yigit.b.ARITASAS\Desktop\Yigit\Data Science\IBM Coursera\C10_Applied Data Science Capstone\Notebook\konak_map.JPG"

#Create an object of tkinter ImageTk
img = ImageTk.PhotoImage(Image.open(path))

#Create a Label Widget to display the text or Image
#label = tk.Label(win, image = img)
#label.pack(fill = "both", expand = "yes")

#win.mainloop()
# Out:
#   File "<ipython-input-185-b796746f1e84>", line 12
#     path = "\Users\yigit.b.ARITASAS\Desktop\Yigit\Data Science\IBM Coursera\C10_Applied Data Science Capstone\Notebook\konak_map.JPG"
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \UXXXXXXXX escape
